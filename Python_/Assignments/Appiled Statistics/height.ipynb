# %% [markdown]
# Applied statistics Lab to check for outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv("D:\\My Repositories\\BTDS-FY_Files-Assignments\\Python_\\Assignments\\Appiled Statistics\\height.csv")

# Display the first few rows of the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       5 # Load the CSV file into a DataFrame
#       6 df = pd.read_csv("D:\\My Repositories\\BTDS-FY_Files-Assignments\\Python_\\Assignments\\Appiled Statistics\\height.csv")
#
# ModuleNotFoundError: No module named 'matplotlib'
