# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the tips dataset

tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Q.1 Draw a scatter plot on a basis of above data

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# ## Q.2 Draw a boxplot on a basis of above dataset

# %%
sns.boxplot(x= 'day', y = 'total_bill', data = tips)
plt.title("Box plot")
plt.show()

# %% [markdown]
# ## Q3 Draw a bar plot

# %%
sns.barplot(x= 'day', y = 'total_bill', data = tips)
plt.title("Bar plot")
plt.show()

# %% [markdown]
# ## Q.4 Violin plot

# %%
sns.violinplot(x= 'day', y = 'total_bill', data = tips)
plt.title("violin plot")
plt.show()

# %% [markdown]
# # Additional Questions for students
#
# ## Q 5. Draw a line plot based on above data using seaborn
# ## Q 6. Draw a cat plot based on above data using seaborn  (hint :- use function sns.catplot)
# ## Q 7. Draw a Swarm plot based on above data using seaborn  (hint :- use function sns.swarmplot)
